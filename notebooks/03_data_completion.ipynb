# %% [markdown]
# PURPOSE: Complete missing metadata for bills without issue tags or governance
#
# WHAT THIS DOES:
# - Identifies bills missing issue tags or governance (~126 bills)
# - Uses LLM to assign issue tags (1-3 per bill)
# - Uses LLM to assign governance categories
# - Validates against existing human-tagged bills
# - Merges with complete bills to create full dataset
#
# OUTPUT: bill_data_completed.csv with all 146 bills fully tagged

# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import json
import yaml
from anthropic import Anthropic
from collections import Counter

sns.set_style("whitegrid")
sns.set_palette("colorblind")
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['font.size'] = 11

print("✓ Libraries loaded")
# Out:
# ✓ Libraries loaded

# %%
try:
    with open('../config.yml', 'r') as f:
        config = yaml.safe_load(f)
    
    api_key = config.get('ANTHROPIC_API_KEY')
    if not api_key:
        raise ValueError("ANTHROPIC_API_KEY not found in config.yml")
    
    print("✓ API key loaded from config.yml")
    
except FileNotFoundError:
    print("✗ config.yml not found in parent directory")
    print("  Create ../config.yml with:")
    print("  ANTHROPIC_API_KEY: sk-ant-your-key-here")
    raise
except Exception as e:
    print(f"✗ Error loading config: {e}")
    raise
# Out:
# ✓ API key loaded from config.yml

# %%
df_bills = pl.read_excel(
    "../data/policy_tracker.xlsx", 
    sheet_name="4. US State - Current Child"
)

print(f"✓ Loaded {len(df_bills):,} bills")

# Count existing tags
has_tags = df_bills.filter(pl.col('Issue Tag').is_not_null())
has_governance = df_bills.filter(pl.col('Governance').is_not_null())

print(f"  Bills with issue tags: {len(has_tags)} ({len(has_tags)/len(df_bills)*100:.1f}%)")
print(f"  Bills with governance: {len(has_governance)} ({len(has_governance)/len(df_bills)*100:.1f}%)")
print(f"  Bills fully complete (both tags + governance): {len(df_bills.filter(pl.col('Issue Tag').is_not_null() & pl.col('Governance').is_not_null()))}")
# Out:
# Could not determine dtype for column 14, falling back to string
# ✓ Loaded 146 bills
#   Bills with issue tags: 20 (13.7%)
#   Bills with governance: 112 (76.7%)
#   Bills fully complete (both tags + governance): 20

# %%
VALID_ISSUE_TAGS = [
    "Accessibility", "Algorithms", "Antitrust", "Artificial intelligence",
    "Authorisation, registration and licensing", "Children", "Civil rights",
    "Competition", "Content moderation/Free Speech", "Cybersecurity",
    "Democracy", "Design and testing standards", "Discrimination",
    "Disinformation", "Education and research", "Employment", "Extremism",
    "Foreign direct investment", "Free speech", "Hate and harassment",
    "Human rights", "Instrument unspecified", "Intellectual Property",
    "International trade", "Internet access", "Labour law", "Liability",
    "National Security", "News and journalism", "Online safety",
    "Other operating conditions", "Polarization", "Privacy", "Public health",
    "Public procurement", "Subsidies and industrial policy", "Taxation",
    "Transparency"
]

print(f"✓ Loaded {len(VALID_ISSUE_TAGS)} valid issue tags")
# Out:
# ✓ Loaded 38 valid issue tags

# %%
DATA_COMPLETION_PROMPT = """You are analyzing US state child online safety legislation to complete missing metadata tags.

**Bill Information:**
State: {state}
Name: {name}
Description: {description}

**Existing Tags:**
Issue Tag 1: {tag1}
Issue Tag 2: {tag2}
Issue Tag 3: {tag3}
Governance: {governance}

---

## TASK: Complete Missing Tags

### Issue Tags
Select 1-3 tags from this list that best describe the bill's PRIMARY focus areas:

{issue_tag_list}

**IMPORTANT CONSTRAINTS:**
- DO NOT select "Children" - this is a child safety bill dataset, so that tag is redundant
- Prioritize SPECIFICITY over generality
- Choose tags that distinguish THIS bill from other child safety bills
- If the bill focuses on online safety broadly, use more specific tags like "Content moderation/Free Speech", "Privacy", "Cybersecurity", etc.

### Governance Category
Select ONE category that best describes the bill's governance approach:

- Content Moderation/Free Speech: Bills regulating harmful content, age verification for adult content
- Privacy/Data Rights: Bills restricting data collection/use from minors
- Platforms + Democracy: Bills requiring platform design changes, impact assessments
- Government Surveillance: Bills creating task forces, studies, or government monitoring programs

If none fit well, leave as null.

---

## OUTPUT FORMAT

Respond with ONLY valid JSON (no markdown, no explanation):

{{
  "issue_tags": ["tag1", "tag2"],
  "governance": "category name or null",
  "reasoning": "Brief explanation of tag choices"
}}
"""

issue_tag_list = "\n".join([f"- {tag}" for tag in VALID_ISSUE_TAGS])
print("✓ Prompt template ready")
# Out:
# ✓ Prompt template ready

# %%
# Bills missing issue tags OR governance
bills_needing_completion = df_bills.filter(
    pl.col('Issue Tag').is_null() | pl.col('Governance').is_null()
)

print(f"\nBills needing completion: {len(bills_needing_completion)}")
print(f"Bills already complete: {len(df_bills) - len(bills_needing_completion)}")
# Out:
# Bills needing completion: 126
# Bills already complete: 20

# %%
print("\n=== RUNNING DATA COMPLETION ===")
print(f"Processing {len(bills_needing_completion)} incomplete bills\n")

client = Anthropic(api_key=api_key)

data_completion_results = []
completion_errors = []

for i, bill in enumerate(bills_needing_completion.iter_rows(named=True), 1):
    print(f"[{i:3}/{len(bills_needing_completion)}] {bill['US State']:15} {bill['Name'][:45]}...")
    
    # Create data completion prompt
    prompt = DATA_COMPLETION_PROMPT.format(
        state=bill['US State'],
        name=bill['Name'],
        description=bill['Description'],
        tag1=bill.get('Issue Tag') or 'None',
        tag2=bill.get('Issue Tag_1') or 'None',
        tag3=bill.get('Issue Tag_2') or 'None',
        governance=bill.get('Governance') or 'None',
        issue_tag_list=issue_tag_list
    )
    
    try:
        message = client.messages.create(
            model="claude-sonnet-4-20250514",
            max_tokens=800,
            temperature=0.0,
            messages=[{"role": "user", "content": prompt}]
        )
        
        text = message.content[0].text.strip()
        if text.startswith('```'):
            text = text.replace('```json', '').replace('```', '').strip()
        
        completion = json.loads(text)
        
        # Store results with metadata
        result = {
            'state': bill['US State'],
            'name': bill['Name'],
            'description': bill['Description'],
            'existing_tag_1': bill.get('Issue Tag'),
            'existing_tag_2': bill.get('Issue Tag_1'),
            'existing_tag_3': bill.get('Issue Tag_2'),
            'existing_governance': bill.get('Governance'),
            'llm_tags': completion.get('issue_tags', []),
            'llm_governance': completion.get('governance'),
            'reasoning': completion.get('reasoning', '')
        }
        
        data_completion_results.append(result)
        
        tags_str = ', '.join(completion.get('issue_tags', []))
        gov_str = completion.get('governance', 'null')
        print(f"     ✓ Tags: {tags_str[:50]}")
        print(f"     ✓ Gov:  {gov_str}")
        
    except Exception as e:
        print(f"     ✗ Error: {e}")
        completion_errors.append({
            'bill': f"{bill['US State']} - {bill['Name']}",
            'error': str(e)
        })

print(f"\n✓ Data completion: {len(data_completion_results)}/{len(bills_needing_completion)} bills")
print(f"  Errors: {len(completion_errors)}")

# Save results
with open('../data/data_completion_results.json', 'w') as f:
    json.dump(data_completion_results, f, indent=2)
print("✓ Saved: ../data/data_completion_results.json")
# Out:
# === RUNNING DATA COMPLETION ===
# Processing 126 incomplete bills
#
# [  1/126] Georgia         Student Technology Protection Act...
#      ✓ Tags: Education and research, Cybersecurity, Online safe
#      ✓ Gov:  Platforms + Democracy
# [  2/126] Idaho           PROTECTION OF MINORS – Adds to existing law t...
#      ✓ Tags: Content moderation/Free Speech, Design and testing
#      ✓ Gov:  Content moderation/Free Speech
# [  3/126] Idaho           PROTECTION OF MINORS – Adds to existing law t...
#      ✓ Tags: Content moderation/Free Speech, Design and testing
#      ✓ Gov:  Content moderation/Free Speech
# [  4/126] Illinois        Creates the Children's Privacy Protection and...
#      ✓ Tags: Privacy, Online safety, Design and testing standar
#      ✓ Gov:  Platforms + Democracy
# [  5/126] Illinois        Creates the Minor Online Data Privacy Act....
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [  6/126] Indiana         Internet safety curricula for schools...
#      ✓ Tags: Education and research, Online safety, Cybersecuri
#      ✓ Gov:  Government Surveillance
# [  7/126] Iowa            An Act relating to civil liability for commer...
#      ✓ Tags: Online safety, Liability, Privacy
#      ✓ Gov:  Content Moderation/Free Speech
# [  8/126] Iowa            An Act relating to social media users under e...
#      ✓ Tags: Online safety, Authorisation, registration and lic
#      ✓ Gov:  Platforms + Democracy
# [  9/126] Iowa            An Act relating to social media data collecti...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [ 10/126] Iowa            An Act relating to parental consent regarding...
#      ✓ Tags: Online safety, Authorisation, registration and lic
#      ✓ Gov:  Privacy/Data Rights
# [ 11/126] Kansas          Requiring commercial entities that produce ma...
#      ✓ Tags: Content moderation/Free Speech, Privacy, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 12/126] Kansas          Require commercial entities that produce mate...
#      ✓ Tags: Content moderation/Free Speech, Privacy, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 13/126] Kansas          Removing liability protections from online pl...
#      ✓ Tags: Liability, Algorithms, Transparency
#      ✓ Gov:  Content Moderation/Free Speech
# [ 14/126] Kentucky        AN ACT relating to consumer data privacy....
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [ 15/126] Kentucky        AN ACT relating to the protection of minors....
#      ✓ Tags: Content moderation/Free Speech, Privacy, Online sa
#      ✓ Gov:  Content Moderation/Free Speech
# [ 16/126] Louisiana       Provides for attorney general investigation f...
#      ✓ Tags: Content moderation/Free Speech, Liability
#      ✓ Gov:  Government Surveillance
# [ 17/126] Louisiana       Provides for liability for publishers and dis...
#      ✓ Tags: Online safety, Liability, Privacy
#      ✓ Gov:  Content Moderation/Free Speech
# [ 18/126] Louisiana       Creates the Secure Online Child Interaction a...
#      ✓ Tags: Privacy, Online safety, Authorisation, registratio
#      ✓ Gov:  Platforms + Democracy
# [ 19/126] Maine           An Act to Protect Children by Modernizing Int...
#      ✓ Tags: Content moderation/Free Speech, Education and rese
#      ✓ Gov:  Content Moderation/Free Speech
# [ 20/126] Maryland        Consumer Protection – Social Media Regulation...
#      ✓ Tags: Online safety, Content moderation/Free Speech, Pri
#      ✓ Gov:  Content Moderation/Free Speech
# [ 21/126] Maryland        Consumer Protection - Online Products and Ser...
#      ✓ Tags: Privacy, Algorithms, Design and testing standards
#      ✓ Gov:  Platforms + Democracy
# [ 22/126] Maryland        Commercial Law - Protection of Minors From Un...
#      ✓ Tags: Design and testing standards, Online safety, Other
#      ✓ Gov:  Privacy/Data Rights
# [ 23/126] Maryland        Consumer Protection – Online Products and Ser...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [ 24/126] Massachusetts   An Act relative to internet privacy rights fo...
#      ✓ Tags: Content moderation/Free Speech, Privacy, Online sa
#      ✓ Gov:  Content Moderation/Free Speech
# [ 25/126] Massachusetts   An Act relative to student and educator data ...
#      ✓ Tags: Privacy, Education and research, Cybersecurity
#      ✓ Gov:  Privacy/Data Rights
# [ 26/126] Massachusetts   An Act concerning media literacy in schools...
#      ✓ Tags: Education and research, Online safety, Disinformat
#      ✓ Gov:  Content Moderation/Free Speech
# [ 27/126] Massachusetts   An Act relative to the enticement of children...
#      ✓ Tags: Online safety, Liability
#      ✓ Gov:  Government Surveillance
# [ 28/126] Massachusetts   An Act relative to transmitting indecent visu...
#      ✓ Tags: Online safety, Hate and harassment, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 29/126] Massachusetts   An Act establishing the Massachusetts Data Pr...
#      ✓ Tags: Privacy, Algorithms, Transparency
#      ✓ Gov:  Privacy/Data Rights
# [ 30/126] Massachusetts   An Act relative to student and educator data ...
#      ✓ Tags: Privacy, Education and research, Cybersecurity
#      ✓ Gov:  Privacy/Data Rights
# [ 31/126] Massachusetts   An Act relative to transmitting indecent visu...
#      ✓ Tags: Online safety, Hate and harassment, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 32/126] Massachusetts   An Act relative to transmitting indecent visu...
#      ✓ Tags: Online safety, Hate and harassment, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 33/126] Minnesota       Social media algorithms that target children ...
#      ✓ Tags: Algorithms, Online safety, Authorisation, registra
#      ✓ Gov:  Platforms + Democracy
# [ 34/126] Minnesota       Human Trafficking and Child Exploitation Prev...
#      ✓ Tags: Content moderation/Free Speech, Online safety, Lia
#      ✓ Gov:  Content Moderation/Free Speech
# [ 35/126] Minnesota       Minnesota Age-Appropriate Design Code Act cre...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [ 36/126] Minnesota       Human Trafficking and Child Exploitation Prev...
#      ✓ Tags: Content moderation/Free Speech, Online safety, Lia
#      ✓ Gov:  Content Moderation/Free Speech
# [ 37/126] Minnesota       Certain social media algorithms that target c...
#      ✓ Tags: Algorithms, Online safety, Authorisation, registra
#      ✓ Gov:  Platforms + Democracy
# [ 38/126] Minnesota       Minnesota Age-Appropriate Design Code Act...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [ 39/126] Mississippi     Minors;  hold entities that publish harmful m...
#      ✓ Tags: Online safety, Liability, Privacy
#      ✓ Gov:  Content Moderation/Free Speech
# [ 40/126] Mississippi     Digital or online resources or databases;  re...
#      ✓ Tags: Content moderation/Free Speech, Online safety
#      ✓ Gov:  Content Moderation/Free Speech
# [ 41/126] Mississippi     Pornographic online and digital/resources for...
#      ✓ Tags: Content moderation/Free Speech, Education and rese
#      ✓ Gov:  Content Moderation/Free Speech
# [ 42/126] Mississippi     Material harmful to minors;  provide for liab...
#      ✓ Tags: Online safety, Liability, Privacy
#      ✓ Gov:  Content Moderation/Free Speech
# [ 43/126] Mississippi     Material harmful to minors;  provide for liab...
#      ✓ Tags: Online safety, Liability, Privacy
#      ✓ Gov:  Content Moderation/Free Speech
# [ 44/126] Missouri        Requires internet service providers to authen...
#      ✓ Tags: Content moderation/Free Speech, Internet access, A
#      ✓ Gov:  Content Moderation/Free Speech
# [ 45/126] Montana         Generally revise pupil data privacy protectio...
#      ✓ Tags: Privacy, Artificial intelligence, Education and re
#      ✓ Gov:  Privacy/Data Rights
# [ 46/126] Montana         Revise internet laws related to material harm...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [ 47/126] Nebraska        Create the offense of digital grooming and pr...
#      ✓ Tags: Online safety, Hate and harassment, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 48/126] Nebraska        Provide requirements regarding access to digi...
#      ✓ Tags: Content moderation/Free Speech, Privacy, Education
#      ✓ Gov:  Content moderation/Free Speech
# [ 49/126] Nevada          Establishes provisions relating to Internet p...
#      ✓ Tags: Privacy, Online safety, Design and testing standar
#      ✓ Gov:  Platforms + Democracy
# [ 50/126] New Hampshire   making an appropriation to support the work o...
#      ✓ Tags: Cybersecurity, National Security
#      ✓ Gov:  Government Surveillance
# [ 51/126] New Hampshire   AN ACT relative to the expectation of privacy...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [ 52/126] New Jersey      Provides that required instruction on sexual ...
#      ✓ Tags: Online safety, Education and research
#      ✓ Gov:  Education and research
# [ 53/126] New Jersey      Establishes "Internet Predator Investigation ...
#      ✓ Tags: Online safety, Taxation, Cybersecurity
#      ✓ Gov:  Government Surveillance
# [ 54/126] New Jersey      One Strike, You're Ours;  adds use of Interne...
#      ✓ Tags: Online safety, Liability, National Security
#      ✓ Gov:  Government Surveillance
# [ 55/126] New Jersey      Human Trafficking and Child Exploitation Prev...
#      ✓ Tags: Content moderation/Free Speech, Online safety, Des
#      ✓ Gov:  Content Moderation/Free Speech
# [ 56/126] New Jersey      Requires sex offenders to report Internet ide...
#      ✓ Tags: Online safety, National Security, Cybersecurity
#      ✓ Gov:  Government Surveillance
# [ 57/126] New Jersey      Concerns social media privacy and data manage...
#      ✓ Tags: Privacy, Design and testing standards, Transparenc
#      ✓ Gov:  Privacy/Data Rights
# [ 58/126] New Jersey      Prohibits social media platforms from using c...
#      ✓ Tags: Design and testing standards, Algorithms, Public h
#      ✓ Gov:  Platforms + Democracy
# [ 59/126] New Jersey      Human Trafficking and Child Exploitation Prev...
#      ✓ Tags: Content moderation/Free Speech, Online safety, Des
#      ✓ Gov:  Content moderation/Free Speech
# [ 60/126] New Jersey      Establishes "Internet Predator Investigation ...
#      ✓ Tags: Online safety, Subsidies and industrial policy, Ta
#      ✓ Gov:  Government Surveillance
# [ 61/126] New Jersey      Provides that required instruction on sexual ...
#      ✓ Tags: Online safety, Education and research
#      ✓ Gov:  Government Surveillance
# [ 62/126] New Jersey      Concerns social media privacy and data manage...
#      ✓ Tags: Privacy, Design and testing standards, Transparenc
#      ✓ Gov:  Privacy/Data Rights
# [ 63/126] New Jersey      Prohibits social media platforms from using c...
#      ✓ Tags: Design and testing standards, Public health, Algor
#      ✓ Gov:  Platforms + Democracy
# [ 64/126] New Mexico      Age Appropriate Design Code Act...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [ 65/126] New York        Directs the commissioner of education to appo...
#      ✓ Tags: Education and research, Online safety
#      ✓ Gov:  Government Surveillance
# [ 66/126] New York        Directs the commissioner of education to appo...
#      ✓ Tags: Education and research, Online safety
#      ✓ Gov:  Government Surveillance
# [ 67/126] New York        Prevents interactive computer service provide...
#      ✓ Tags: Content moderation/Free Speech, Algorithms, Liabil
#      ✓ Gov:  Content moderation/Free Speech
# [ 68/126] New York        Relates to creating a set of media literacy s...
#      ✓ Tags: Education and research, Online safety, Privacy
#      ✓ Gov:  Platforms + Democracy
# [ 69/126] New York        Prohibits cyber-bullying...
#      ✓ Tags: Hate and harassment, Online safety, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 70/126] New York        Relates to enacting the New York child data p...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Privacy/Data Rights
# [ 71/126] New York        Offers parental controls for internet service...
#      ✓ Tags: Internet access, Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [ 72/126] New York        Relates to the uniform employee and student o...
#      ✓ Tags: Privacy, Education and research
#      ✓ Gov:  Privacy/Data Rights
# [ 73/126] New York        Relates to prohibiting a person required to r...
#      ✓ Tags: Online safety, Authorisation, registration and lic
#      ✓ Gov:  Content Moderation/Free Speech
# [ 74/126] New York        Prevents interactive computer service provide...
#      ✓ Tags: Content moderation/Free Speech, Algorithms, Liabil
#      ✓ Gov:  Content moderation/Free Speech
# [ 75/126] New York        Relates to enacting the New York child data p...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [ 76/126] New York        Relates to the registration information requi...
#      ✓ Tags: Online safety, Privacy, Transparency
#      ✓ Gov:  Government Surveillance
# [ 77/126] New York        Relates to the regulation of social media com...
#      ✓ Tags: Online safety, Privacy, Authorisation, registratio
#      ✓ Gov:  Privacy/Data Rights
# [ 78/126] North Carolina  Age Verification to Protect Children Act....
#      ✓ Tags: Online safety, Content moderation/Free Speech
#      ✓ Gov:  Content Moderation/Free Speech
# [ 79/126] North Carolina  Social Media Algorithmic Control in IT Act....
#      ✓ Tags: Algorithms, Privacy, Transparency
#      ✓ Gov:  Privacy/Data Rights
# [ 80/126] North Carolina  Let Parents Choose/Sammy's Law of 2023...
#      ✓ Tags: Authorisation, registration and licensing, Online
#      ✓ Gov:  Platforms + Democracy
# [ 81/126] North Dakota    [R]elating to the definition of a public libr...
#      ✓ Tags: Content moderation/Free Speech, Education and rese
#      ✓ Gov:  Content moderation/Free Speech
# [ 82/126] Ohio            Regards education records and student data pr...
#      ✓ Tags: Privacy, Education and research
#      ✓ Gov:  Privacy/Data Rights
# [ 83/126] Oklahoma        Human trafficking and child exploitation;  cr...
#      ✓ Tags: Content moderation/Free Speech, Online safety, Lia
#      ✓ Gov:  Content moderation/Free Speech
# [ 84/126] Oregon          Relating to business's use of age-appropriate...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [ 85/126] Pennsylvania    An Act providing for protection of certain pe...
#      ✓ Tags: Privacy, Transparency
#      ✓ Gov:  Privacy/Data Rights
# [ 86/126] Pennsylvania    An Act amending Title 18 (Crimes and Offenses...
#      ✓ Tags: Online safety, Content moderation/Free Speech
#      ✓ Gov:  Content Moderation/Free Speech
# [ 87/126] Pennsylvania    An Act amending the act of November 30, 2004 ...
#      ✓ Tags: Content moderation/Free Speech
#      ✓ Gov:  Content moderation/Free Speech
# [ 88/126] Rhode Island    AN ACT RELATING TO EDUCATION -- STUDENT COMPU...
#      ✓ Tags: Privacy, Education and research
#      ✓ Gov:  Privacy/Data Rights
# [ 89/126] Rhode Island    AN ACT RELATING TO COMMERCIAL LAW -- GENERAL ...
#      ✓ Tags: Privacy, Transparency
#      ✓ Gov:  Privacy/Data Rights
# [ 90/126] Rhode Island    AN ACT RELATING TO COMMERCIAL LAW -- GENERAL ...
#      ✓ Tags: Privacy, Transparency
#      ✓ Gov:  Privacy/Data Rights
# [ 91/126] South Carolina  Child Online Safety Act...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [ 92/126] South Carolina  Child Online Safety Act...
#      ✓ Tags: Content moderation/Free Speech, Online safety
#      ✓ Gov:  Content Moderation/Free Speech
# [ 93/126] South Carolina  A BILL TO AMEND THE SOUTH CAROLINA CODE OF LA...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [ 94/126] South Carolina  Social media regulation...
#      ✓ Tags: Algorithms, Online safety, Authorisation, registra
#      ✓ Gov:  Platforms + Democracy
# [ 95/126] South Carolina  Children's Default to Safety Act...
#      ✓ Tags: Content moderation/Free Speech, Design and testing
#      ✓ Gov:  Content moderation/Free Speech
# [ 96/126] South Dakota    An Act to provide liability for the publishin...
#      ✓ Tags: Online safety, Privacy, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [ 97/126] Tennessee       Enacts the "Tennessee Information Protection ...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [ 98/126] Tennessee       Enacts the "Youth Mental Health Safety Act....
#      ✓ Tags: Design and testing standards, Public health, Onlin
#      ✓ Gov:  Platforms + Democracy
# [ 99/126] Texas           Relating to the regulation of the collection,...
#      ✓ Tags: Privacy, Online safety, Authorisation, registratio
#      ✓ Gov:  Privacy/Data Rights
# [100/126] Texas           Relating to the protection of minors from har...
#      ✓ Tags: Algorithms, Online safety, Content moderation/Free
#      ✓ Gov:  Platforms + Democracy
# [101/126] Texas           Relating to prohibiting use of social media p...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [102/126] Texas           Relating to restricting access to sexual mate...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [103/126] Texas           Relating to prohibiting social media platform...
#      ✓ Tags: Algorithms, Privacy, Online safety
#      ✓ Gov:  Platforms + Democracy
# [104/126] Texas           Relating to requirements for the use and tran...
#      ✓ Tags: Privacy, Online safety, Education and research
#      ✓ Gov:  Privacy/Data Rights
# [105/126] Texas           Relating to restricting access to sexual mate...
#      ✓ Tags: Online safety, Privacy, Liability
#      ✓ Gov:  Content Moderation/Free Speech
# [106/126] Texas           Relating to restricting access to sexual mate...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [107/126] Texas           Relating to online agreements between certain...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [108/126] Texas           Relating to the regulation of Internet produc...
#      ✓ Tags: Privacy, Design and testing standards, Online safe
#      ✓ Gov:  Platforms + Democracy
# [109/126] Texas           Relating to requirements for certain Internet...
#      ✓ Tags: Content moderation/Free Speech, Online safety
#      ✓ Gov:  Content moderation/Free Speech
# [110/126] Texas           Relating to requirements for certain Internet...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [111/126] Texas           Relating to restricting access to sexual mate...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [112/126] Utah            Social Media Usage Amendments...
#      ✓ Tags: Design and testing standards, Algorithms, Liabilit
#      ✓ Gov:  Platforms + Democracy
# [113/126] Utah            Social Media Regulation Amendments...
#      ✓ Tags: Privacy, Online safety, Authorisation, registratio
#      ✓ Gov:  Privacy/Data Rights
# [114/126] Utah            Online Pornography Viewing Age Requirements...
#      ✓ Tags: Online safety, Privacy, Content moderation/Free Sp
#      ✓ Gov:  Content Moderation/Free Speech
# [115/126] Vermont         An act relating to the Vermont Broadband Inte...
#      ✓ Tags: Privacy, Internet access
#      ✓ Gov:  Privacy/Data Rights
# [116/126] Vermont         An act relating to funding for the Vermont In...
#      ✓ Tags: Cybersecurity, Subsidies and industrial policy
#      ✓ Gov:  Government Surveillance
# [117/126] Virginia        Consumer Data Protection Act;  protections fo...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [118/126] Virginia        Consumer Data Protection Act;  protections fo...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [119/126] Virginia        Civil liability for publishing or distributin...
#      ✓ Tags: Online safety, Liability, Privacy
#      ✓ Gov:  Content Moderation/Free Speech
# [120/126] West Virginia   Providing online privacy protection laws for ...
#      ✓ Tags: Privacy, Online safety
#      ✓ Gov:  Privacy/Data Rights
# [121/126] West Virginia   Relating to online privacy protection for min...
#      ✓ Tags: Content moderation/Free Speech, Privacy, Online sa
#      ✓ Gov:  Content Moderation/Free Speech
# [122/126] West Virginia   Protection of minors from harmful material on...
#      ✓ Tags: Content moderation/Free Speech, Privacy, Online sa
#      ✓ Gov:  Content Moderation/Free Speech
# [123/126] West Virginia   Relating to the Consumer Data Protection Act ...
#      ✓ Tags: Privacy, Transparency
#      ✓ Gov:  Privacy/Data Rights
# [124/126] Wisconsin       Relating to: prostitution crime surcharge and...
#      ✓ Tags: Taxation, Cybersecurity
#      ✓ Gov:  Government Surveillance
# [125/126] Wisconsin       Relating to: pupil or minor access to harmful...
#      ✓ Tags: Content moderation/Free Speech, Education and rese
#      ✓ Gov:  Content Moderation/Free Speech
# [126/126] Wisconsin       Relating to: prostitution crime surcharge and...
#      ✓ Tags: Taxation, Cybersecurity
#      ✓ Gov:  Government Surveillance
#
# ✓ Data completion: 126/126 bills
#   Errors: 0
# ✓ Saved: ../data/data_completion_results.json

# %%
print("\n\n=== CREATING COMPLETED DATASET ===\n")

# Create lookup for LLM results
llm_lookup = {
    (r['state'], r['name']): r 
    for r in data_completion_results
}

# Merge all bills (complete + newly completed)
rows = []
for bill in df_bills.iter_rows(named=True):
    key = (bill['US State'], bill['Name'])
    
    # Check if this bill was processed by LLM
    if key in llm_lookup:
        llm_result = llm_lookup[key]
        row = {
            'US State': bill['US State'],
            'Name': bill['Name'],
            'Description': bill['Description'],
            'Issue_Tag_1': llm_result['llm_tags'][0] if len(llm_result['llm_tags']) > 0 else None,
            'Issue_Tag_2': llm_result['llm_tags'][1] if len(llm_result['llm_tags']) > 1 else None,
            'Issue_Tag_3': llm_result['llm_tags'][2] if len(llm_result['llm_tags']) > 2 else None,
            'Governance': llm_result['llm_governance'],
            'Source': 'LLM'
        }
    else:
        # Bill already had complete data
        row = {
            'US State': bill['US State'],
            'Name': bill['Name'],
            'Description': bill['Description'],
            'Issue_Tag_1': bill.get('Issue Tag'),
            'Issue_Tag_2': bill.get('Issue Tag_1'),
            'Issue_Tag_3': bill.get('Issue Tag_2'),
            'Governance': bill.get('Governance'),
            'Source': 'Original'
        }
    
    rows.append(row)

df_completed = pl.DataFrame(rows)

print(f"✓ Created completed dataset: {df_completed.shape}")
print(f"  Bills from original data: {len(df_completed.filter(pl.col('Source') == 'Original'))}")
print(f"  Bills completed by LLM: {len(df_completed.filter(pl.col('Source') == 'LLM'))}")

# Save
df_completed.write_csv('../data/bill_data_completed.csv')
print("✓ Saved: ../data/bill_data_completed.csv")
# Out:
# === CREATING COMPLETED DATASET ===
#
# ✓ Created completed dataset: (146, 8)
#   Bills from original data: 20
#   Bills completed by LLM: 126
# ✓ Saved: ../data/bill_data_completed.csv
